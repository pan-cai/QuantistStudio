# %% [markdown]
# ##### """
#  Factor1 = DataAPI.MktStockFactorsOneDayGet(tradeDate=yesterday,secID=account.universe,field=['secID','LCAP'],pandas="1")    #提取股票翅中所有股票的对数市值
# 36
#         df1=list(Factor1.sort('LCAP').secID)
# 37
#         universe1=df1[0:int(len(df1)*0.7)]          #剔除 市值最大的前30%
# 38
#         #选取PE 净资产增长率 净利润增长率 ROE 经营活动产生的现金流量净额与经营活动净收益之比
# 39
#         df2=DataAPI.MktStockFactorsOneDayGet(tradeDate=yesterday,secID=universe1,field=u"secID,PE,NetAssetGrowRate,NetProfitGrowRate,ROE,NOCFToOperatingNI",pandas="1").set_index('secID')
# 40
#         df3=df2[df2.PE>0].dropna() #剔除PE为负的标的
# 41
#         #对选取因子进行去极值 行业中心化 标准化
# 42
#         PE=standardize(neutralize(winsorize(df3.PE.to_dict()),yesterday))
# 43
#         NetAssetGrowRate=standardize(neutralize(winsorize(df3.NetAssetGrowRate.to_dict()),yesterday))
# 44
#         NetProfitGrowRate=standardize(neutralize(winsorize(df3.NetProfitGrowRate.to_dict()),yesterday))
# 45
#         ROE=standardize(neutralize(winsorize(df3.ROE.to_dict()),yesterday))
# 46
#         NOCFToOperatingNI=standardize(neutralize(winsorize(df3.NOCFToOperatingNI.to_dict()),yesterday))
# 47
#
# 48
#         S=DataFrame(np.nan,index=map(lambda x: x[:11],universe1),columns=['PE','NetAssetGrowRate','NetProfitGrowRate','ROE','NOCFToOperatingNI'])
# 49
#         S['PE'][PE.keys()]=PE.values()
# 50
#         S['NetAssetGrowRate'][NetAssetGrowRate.keys()]=NetAssetGrowRate.values()
# 51
#         S['NetProfitGrowRate'][NetProfitGrowRate.keys()]=NetProfitGrowRate.values()
# 52
#         S['ROE'][ROE.keys()]=ROE.values()
# 53
#         S['NOCFToOperatingNI'][NOCFToOperatingNI.keys()]=NOCFToOperatingNI.values()
# 54
#
# 55
#         SCO=S.dropna()
# 56
#         #打分 将净资产增长率 净利润增长率 ROE 分为成长性一类   现金流和PE分别为为现金流类和估值类 其中PE定义为反向指标
# 57
#         SCO['score']=(SCO['NetAssetGrowRate']+SCO['NetProfitGrowRate']+SCO['ROE'])/3+SCO['NOCFToOperatingNI']-SCO['PE']
# 58
#         #选取分数最高的前50只准备买入
# 59
#         buylist=list(SCO.sort('score',ascending=0).index)[:50]
#
# """

# %% [markdown]
# ##### """
# 策略思路
# •	每个季度，计算沪深300成分股资产负债表中的 现金及现金等价物/总资产 ，数值以最近一次披露的财报为准
# •	清仓，选出该比率最大的前30只股票，将资金分成30份，分别买入
# •	每60个交易日调仓一次
#
# 看财报的小工具，通过对关键财务数据的挖掘与对比，获取对股票质地最直观的认识。本文计划4篇，分别对应资产负债表、利润表、现金流量表和交叉分析。
# 由于本人非财务工作者，具体细节难免会有疏漏，有问题请留言，我再改改代码！
#
#   #资产负债表分析 --- 流动资产结构图
#   label = [u'货币资金',u'结算备付金',u'拆出资金',u'交易性金融资产',u'应收票据',
# 103
#              u'应收账款',u'预付款项',u'应收保费',u'应收分保账款',
# 104
#              u'应收分保合同准备金',u'应收利息',u'应收股利',u'其他应收款',
# 105
#              u'买入返售金融资产',u'存货',u'一年内到期的非流动资产',u'其他流动资产']
# #资产负债表分析 --- 非流动资产结构图
# label = [u'持有至到期投资',u'长期股权投资',u'投资性房地产',u'固定资产',u'在建工程',
# 151
#              u'工程物资',u'固定资产清理',u'生产性生物资产',u'无形资产',
# 152
#              u'商誉',u'长期待摊费用',u'递延所得税资产',u'其他非流动资产',
# 153
#              u'长期应收款',u'油气资产',u'开发支出']
# 179
# #资产负债表分析 --- 流动负债结构图
#   label = [u'短期借款',u'向中央银行借款',u'吸收存款及同业存放',u'拆入资金',u'交易性金融负债',
# 201
#              u'应付票据',u'应付账款',u'预收款项',u'卖出回购金融资产款',
# 202
#              u'应付手续费及佣金',u'应付职工薪酬',u'应交税费',u'应付利息',
# 203
#              u'应付股利',u'其他应付款',u'应付分保账款',u'保险合同准备金',
# 204
#              u'代理买卖证券款',u'代理承销证券款',u'一年内到期的非流动负债',u'其他流动负债']
# 资产负债表分析 --- 非流动负债结构图
#     label = [u'长期借款',u'应付债券',u'长期应付款',u'专项应付款',u'预计负债',
# 245
#              u'递延所得税负债',u'其他非流动负债']
# 272
# #资产负债表分析 --- 所有者权益结构图
#   label = [u'实收资本',u'资本公积',u'减:库存股',u'专项储备',u'盈余公积',
# 288
#              u'一般风险准备',u'未分配利润',u'外币报表折算差额']
# 资产负债表分析
# •	资产负债结构图：用来分析 流动资产、非流动资产、流动负债、非流动负债、所有者权益变动趋势
# •	总净资产变动图：用来分析 总资产、净资产的变动趋势
# •	流动资产结构图：用来分析 流动资产组成结构、及其变化趋势
# •	非流动资产结构图：用来分析 非流动资产组成结构、及其变化趋势
# •	流动负债结构图：用来分析 流动负债 组成结构、及其变化趋势
# •	非流动负债结构图：用来分析 非流动负债 组成结构、及其变化趋势
# •	所有者权益结构图：用来分析 所有者权益 组成结构、及其变化趋势
#
#
# """

# %% [markdown]
# ##### """
# 挑选基本面好的便宜股票（二）
# 策略基本思路是：选出总资产小，净利润增长率高的一个股票池，将股票池按照价格从低到高排序，优先买入低价股票，若买入价为X，在股价超过X后将其卖出，并补进新的优先级高的股票。
# 这是对之前“挑选基本面好的便宜股票”的一个改进，实现了标杆价格X的动态化。
# 增长情况感人，将基准变成直线！
#
# """

# %%
import urllib.request
import json
headers = {#'X-Requested-With': 'XMLHttpRequest',
           #'Referer': 'http://xueqiu.com/p/ZH010389',
           'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64; rv:38.0) Gecko/20100101 Firefox/38.0',
           #'Host': 'xueqiu.com',
           #'Connection':'keep-alive',
           #'Accept':'*/*',
           'cookie':'s=iabht2os.1dgjn9z; xq_a_token=02a16c8dd2d87980d1b3ddced673bd6a74288bde; xq_r_token=024b1e233fea42dd2e0a74832bde2c914ed30e79; __utma=1.2130135756.1433017807.1433017807.1433017807.1;'
           '__utmc=1; __utmz=1.1433017807.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); Hm_lvt_1db88642e346389874251b5a1eded6e3=1433017809; Hm_lpvt_1db88642e346389874251b5a1eded6e3=1433017809'}
url = 'http://xueqiu.com/cubes/rebalancing/history.json?cube_symbol=ZH010389&count=20&page=1'
req = urllib.request.Request(url,headers=headers)
html = urllib.request.urlopen(req).read().decode('utf-8')
#print(html)
data = json.loads(html)
print('股票名称',end=':')
print(data['list'][0]['rebalancing_histories'][0]['stock_name'],end='   持仓变化')
print(data['list'][0]['rebalancing_histories'][0]['prev_weight'],end='-->')
print(data['list'][0]['rebalancing_histories'][0]['target_weight'])
print('股票名称',end=':')
print(data['list'][0]['rebalancing_histories'][1]['stock_name'],end='   持仓变化')
print(data['list'][0]['rebalancing_histories'][1]['prev_weight'],end='-->')
print(data['list'][0]['rebalancing_histories'][1]['target_weight'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-416cb579edba> in <module>()
#      11 url = 'http://xueqiu.com/cubes/rebalancing/history.json?cube_symbol=ZH010389&count=20&page=1'
#      12 req = urllib.request.Request(url,headers=headers)
# ---> 13 html = urllib.request.urlopen(req).read().decode('utf-8')
#      14 #print(html)
#      15 data = json.loads(html)
#
# /usr/local/python35/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     160     else:
#     161         opener = _opener
# --> 162     return opener.open(url, data, timeout)
#     163
#     164 def install_opener(opener):
#
# /usr/local/python35/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     469         for processor in self.process_response.get(protocol, []):
#     470             meth = getattr(processor, meth_name)
# --> 471             response = meth(req, response)
#     472
#     473         return response
#
# /usr/local/python35/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     579         if not (200 <= code < 300):
#     580             response = self.parent.error(
# --> 581                 'http', request, response, code, msg, hdrs)
#     582
#     583         return response
#
# /usr/local/python35/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     501             http_err = 0
#     502         args = (dict, proto, meth_name) + args
# --> 503         result = self._call_chain(*args)
#     504         if result:
#     505             return result
#
# /usr/local/python35/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     441         for handler in handlers:
#     442             func = getattr(handler, meth_name)
# --> 443             result = func(*args)
#     444             if result is not None:
#     445                 return result
#
# /usr/local/python35/lib/python3.5/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     684         fp.close()
#     685
# --> 686         return self.parent.open(new, timeout=req.timeout)
#     687
#     688     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/local/python35/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     469         for processor in self.process_response.get(protocol, []):
#     470             meth = getattr(processor, meth_name)
# --> 471             response = meth(req, response)
#     472
#     473         return response
#
# /usr/local/python35/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     579         if not (200 <= code < 300):
#     580             response = self.parent.error(
# --> 581                 'http', request, response, code, msg, hdrs)
#     582
#     583         return response
#
# /usr/local/python35/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     507         if http_err:
#     508             args = (dict, 'default', 'http_error_default') + orig_args
# --> 509             return self._call_chain(*args)
#     510
#     511 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/local/python35/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     441         for handler in handlers:
#     442             func = getattr(handler, meth_name)
# --> 443             result = func(*args)
#     444             if result is not None:
#     445                 return result
#
# /usr/local/python35/lib/python3.5/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     587 class HTTPDefaultErrorHandler(BaseHandler):
#     588     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 589         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     590
#     591 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request
